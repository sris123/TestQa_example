# %%
_predict_df = "select (Version.[Version Name]*Product.[Product].[208821]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"

from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource,PluginSetting

# register inputs
predict_df = O9DataLake.register("predict_df",data_source = DataSource.LS, entity_type = ResourceType.IBPL, query = _predict_df,plugin_setting = PluginSetting.Inputs)
#systemreport = O9DataLake.register("newsysreportq4",data_source = DataSource.LIVEFRAME,entity_type = ResourceType.LIVEFRAME,plugin_setting = PluginSetting.Inputs)


# register slice dimension
O9DataLake.register("Product.[Product]", data_source = DataSource.LS, entity_type = ResourceType.IBPL, plugin_setting = PluginSetting.SliceDimension)

# register outputs
O9DataLake.register("output1",data_source = DataSource.LS,entity_type = ResourceType.IBPL, plugin_setting = PluginSetting.Outputs)


# register script params
script_params = O9DataLake.register({"var1":"50","var2":"Test1","var3":"newparam","var4":"80"}, data_source = DataSource.LS, plugin_setting = PluginSetting.ScriptParam)

# %%
O9DataLake.inputs
# Out:
# {'predict_df': {'name': 'predict_df',
#   'resource_type': <ResourceType.IBPL: 'ibpl_query'>,
#   'data_source': <DataSource.LS: 'liveserver'>,
#   'query': 'select (Version.[Version Name]*Product.[Product].[208821]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});',
#   'std_count_limit': '200000',
#   'df':     Version.[Version Name]  Product.[Product] Time.[FiscalWeek]  \
#   0       CurrentWorkingView             208821          W49-2015
#   1       CurrentWorkingView             208821          W50-2015
#   2       CurrentWorkingView             208821          W51-2015
#   3       CurrentWorkingView             208821          W52-2015
#   4       CurrentWorkingView             208821          W01-2016
#   ..                     ...                ...               ...
#   155     CurrentWorkingView             208821          W48-2018
#   156     CurrentWorkingView             208821          W49-2018
#   157     CurrentWorkingView             208821          W50-2018
#   158     CurrentWorkingView             208821          W51-2018
#   159     CurrentWorkingView             208821          W52-2018
#
#       SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
#   0                      ALL                 ALL                    NaN
#   1                      ALL                 ALL                    NaN
#   2                      ALL                 ALL                    NaN
#   3                      ALL                 ALL                    NaN
#   4                      ALL                 ALL                    NaN
#   ..                     ...                 ...                    ...
#   155                    ALL                 ALL                    NaN
#   156                    ALL                 ALL                    NaN
#   157                    ALL                 ALL                    NaN
#   158                    ALL                 ALL                    NaN
#   159                    ALL                 ALL                    NaN
#
#        Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
#   0                      NaN                2              NaN             NaN
#   1                      NaN                2              NaN             NaN
#   2                      NaN                2              NaN             NaN
#   3                      NaN                2              NaN             NaN
#   4                      NaN                2              NaN             NaN
#   ..                     ...              ...              ...             ...
#   155                    0.5                1              1.0             NaN
#   156                    NaN                1              NaN             NaN
#   157                    NaN                1              NaN             NaN
#   158                    NaN                1              NaN             NaN
#   159                    NaN                1              NaN             NaN
#
#   [160 rows x 10 columns]}}

# %%
# fetching inputs
predict_df = O9DataLake.get('predict_df')
#input_df = O9DataLake.get('input_df')
#liveinput = O9DataLake.get('WeeklySales')

# fetching script params
value1 = O9DataLake.get_script_param("var1")
value2 = O9DataLake.get_script_param("var2")

# %%
#user script

# package imports
import logging
from sklearn import tree

# initialize output variables
output1 = None
output2 = None

# initialize logger
logger = logging.getLogger('o9_logger')

logger.debug(f'predict_df dataframe:  {predict_df.shape}')
#logger.debug(f'input_df dataframe:  {input_df.shape}')
#logger.debug(f'liveinput dataframe:  {liveinput.shape}')
logger.debug(f'script param var1 value: {value1}')
logger.debug(f'script param var2 value: {value2}')
# Out:
# 2025-04-28 18:17:17,724 - o9_logger - DEBUG  - predict_df dataframe:  (160, 10)
# 2025-04-28 18:17:17,725 - o9_logger - DEBUG  - script param var1 value: 50
# 2025-04-28 18:17:17,726 - o9_logger - DEBUG  - script param var2 value: Test1

# %%
#pushing outputs to Live Server(make sure all dimensions,measures present in LiveServer)
O9DataLake.put('output1', predict_df)
#O9DataLake.put('output2', output2)
