# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product].[196426]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
query2 = "select (Version.[Version Name]*Product.[Product].[196426]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1) 
O9DataLake.register("DPBaseInputs",DataSource.LS, ResourceType.IBPL, query2)
# Out:
# 2023-01-05 16:06:36,174 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:06:36,177 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:06:36,292 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:06:41,299 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:06:41,302 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:06:41,461 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:06:46,480 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:06:46,483 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:06:46,600 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:06:51,609 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:06:51,612 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:06:51,749 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
# 5     CurrentWorkingView            196426          W42-2017
# 6     CurrentWorkingView            196426          W44-2017
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                   11.0
# 1                    ALL                 ALL                   11.0
# 2                    ALL                 ALL                   11.0
# 3                    ALL                 ALL                   11.0
# 4                    ALL                 ALL                   11.0
# 5                    ALL                 ALL                   11.0
# 6                    ALL                 ALL                   11.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
# 5                    NaN              NaN              NaN            10.0
# 6                    NaN              NaN              NaN            10.0

# %%
sales = O9DataLake.get('sales_df')
sales
# Out:
# 2023-01-05 16:06:56,787 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:06:56,790 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:06:56,898 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:07:01,907 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:07:01,911 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:02,015 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
# 5     CurrentWorkingView            196426          W42-2017
# 6     CurrentWorkingView            196426          W44-2017
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                   11.0
# 1                    ALL                 ALL                   11.0
# 2                    ALL                 ALL                   11.0
# 3                    ALL                 ALL                   11.0
# 4                    ALL                 ALL                   11.0
# 5                    ALL                 ALL                   11.0
# 6                    ALL                 ALL                   11.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
# 5                    NaN              NaN              NaN            10.0
# 6                    NaN              NaN              NaN            10.0

# %%
dpbaseinputs = O9DataLake.get('DPBaseInputs')
O9DataLake.put('out_df1',sales)
# Out:
# 2023-01-05 16:07:07,053 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:07:07,057 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:07,163 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:07:12,172 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 16:07:12,175 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:12,270 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-05 16:07:17,293 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:17,407 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=11qx4vtyj1uj45ka2qptcabm HTTP/1.1" 200 None
# 2023-01-05 16:07:17,411 : srishtisingh_5502 :Uploading LOCAL file: /tmp/tmprvcpxew4/Fact.out_df1.csv
# 2023-01-05 16:07:17,412 : srishtisingh_5502 :Is the file parquet: False
# 2023-01-05 16:07:17,413 : srishtisingh_5502 :Uploading /tmp/tmprvcpxew4/Fact.out_df1.csv to Live Server cloud
# 2023-01-05 16:07:17,413 : srishtisingh_5502 :File size less than 256 MB
# 2023-01-05 16:07:17,415 : srishtisingh_5502 :Uploading to /fileUpload endpoint
# 2023-01-05 16:07:17,415 : srishtisingh_5502 :Uploading /tmp/tmprvcpxew4/Fact.out_df1.csv to Live Server cloud
# 2023-01-05 16:07:17,419 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:19,776 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/upload/fileUpload HTTP/1.1" 200 None
# 2023-01-05 16:07:19,779 : srishtisingh_5502 :Uploaded the file successfully
# 2023-01-05 16:07:19,781 : srishtisingh_5502 :Uploading cloud files at: "azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2"
# 2023-01-05 16:07:19,782 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/framework/sessions/session]
# 2023-01-05 16:07:19,785 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:19,917 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 None
# 2023-01-05 16:07:19,921 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-05 16:07:19,922 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/user]
# 2023-01-05 16:07:19,924 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:20,220 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 None
# 2023-01-05 16:07:20,234 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:20,325 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=11qx4vtyj1uj45ka2qptcabm HTTP/1.1" 200 None
# 2023-01-05 16:07:20,330 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 16:07:22,975 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 None
# 2023-01-05 16:07:22,979 : srishtisingh_5502 :200, OK
# 2023-01-05 16:07:22,980 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.out_df1.csv\",\"SheetName\":\"Fact.out_df1.csv\",\"TotalRows\":7,\"ProcessedRows\":7,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [7]. Successfully Processed Rows: [7].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2\"}]","QueryGuid":"826c8033-b234-413d-a8f9-dfde8da0b752","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsActuals","Mean Pricing Save PCT","Placement Count","Promotion Count","DPSellOutPrice"]}}}}
# 2023-01-05 16:07:22,981 : srishtisingh_5502 :{'FileName': 'Fact.out_df1.csv', 'SheetName': 'Fact.out_df1.csv', 'TotalRows': 7, 'ProcessedRows': 7, 'Status': 'Success', 'Messages': ['Total Rows: [7]. Successfully Processed Rows: [7].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2'}
