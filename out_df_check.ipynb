# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]}) limit 10;"
query2 = "select (Version.[Version Name]*Product.[Product].[196426]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1)
O9DataLake.register("DPBaseInputs",DataSource.LS, ResourceType.IBPL, query2)
# Out:
# 2023-01-18 10:15:54,151 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:15:54,156 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:15:54,338 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:15:59,346 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:15:59,351 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:15:59,509 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:04,528 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:04,532 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:04,636 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:09,644 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:09,648 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:09,742 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
# 5     CurrentWorkingView            196426          W42-2017
# 6     CurrentWorkingView            196426          W44-2017
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                   12.0
# 1                    ALL                 ALL                   12.0
# 2                    ALL                 ALL                   12.0
# 3                    ALL                 ALL                   12.0
# 4                    ALL                 ALL                   12.0
# 5                    ALL                 ALL                   12.0
# 6                    ALL                 ALL                   12.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
# 5                    NaN              NaN              NaN            10.0
# 6                    NaN              NaN              NaN            10.0

# %%
#getting input from dataLake

sales = O9DataLake.get('sales_df')
dpbaseinputs = O9DataLake.get('DPBaseInputs')

#User Script
import logging
logger = logging.getLogger('o9_logger')
logger.info(f'Records count in sales dataframe : {sales.shape}')
logger.info(f'Records count in DPBaseInputs dataframe : {dpbaseinputs.shape}')
# Out:
# 2023-01-18 10:16:21,853 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:21,857 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:22,018 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:27,026 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:27,030 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:27,132 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:32,151 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:32,154 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:32,256 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:37,265 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-18 10:16:37,268 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:37,373 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:42,391 : srishtisingh_5502 :Records count in sales dataframe : (10, 10)
# 2023-01-18 10:16:42,393 : srishtisingh_5502 :Records count in DPBaseInputs dataframe : (7, 10)

# %%
dpbaseinputs2 = dpbaseinputs.head(10)

# %%
#pushing output to the DataLake
O9DataLake.put('out_df2',dpbaseinputs2)
# Out:
# 2023-01-18 10:16:49,154 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:49,230 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=vley5czip4nrrgn11vfdodhl HTTP/1.1" 200 None
# 2023-01-18 10:16:49,233 : srishtisingh_5502 :Uploading LOCAL file: /tmp/tmpocpv6jia/Fact.out_df2.csv
# 2023-01-18 10:16:49,234 : srishtisingh_5502 :Is the file parquet: False
# 2023-01-18 10:16:49,235 : srishtisingh_5502 :Uploading /tmp/tmpocpv6jia/Fact.out_df2.csv to Live Server cloud
# 2023-01-18 10:16:49,236 : srishtisingh_5502 :File size less than 256 MB
# 2023-01-18 10:16:49,237 : srishtisingh_5502 :Uploading to /fileUpload endpoint
# 2023-01-18 10:16:49,238 : srishtisingh_5502 :Uploading /tmp/tmpocpv6jia/Fact.out_df2.csv to Live Server cloud
# 2023-01-18 10:16:49,240 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:51,516 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/upload/fileUpload HTTP/1.1" 200 None
# 2023-01-18 10:16:51,519 : srishtisingh_5502 :Uploaded the file successfully
# 2023-01-18 10:16:51,520 : srishtisingh_5502 :Uploading cloud files at: "azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCg8WP_zhESrm1SWr7g0Bvw6xbuOo1m2iCnwCcv-M_pkA2"
# 2023-01-18 10:16:51,521 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/framework/sessions/session]
# 2023-01-18 10:16:51,523 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:51,614 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 None
# 2023-01-18 10:16:51,616 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-18 10:16:51,617 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/user]
# 2023-01-18 10:16:51,620 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:52,043 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 None
# 2023-01-18 10:16:52,049 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:52,145 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=vley5czip4nrrgn11vfdodhl HTTP/1.1" 200 None
# 2023-01-18 10:16:52,151 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-18 10:16:54,644 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 None
# 2023-01-18 10:16:54,648 : srishtisingh_5502 :200, OK
# 2023-01-18 10:16:54,649 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.out_df2.csv\",\"SheetName\":\"Fact.out_df2.csv\",\"TotalRows\":7,\"ProcessedRows\":7,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [7]. Successfully Processed Rows: [7].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCg8WP_zhESrm1SWr7g0Bvw6xbuOo1m2iCnwCcv-M_pkA2\"}]","QueryGuid":"b2cf6c4b-8f55-4404-bbfa-d39ece643101","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsActuals","Mean Pricing Save PCT","Placement Count","Promotion Count","DPSellOutPrice"]}}}}
# 2023-01-18 10:16:54,650 : srishtisingh_5502 :{'FileName': 'Fact.out_df2.csv', 'SheetName': 'Fact.out_df2.csv', 'TotalRows': 7, 'ProcessedRows': 7, 'Status': 'Success', 'Messages': ['Total Rows: [7]. Successfully Processed Rows: [7].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCg8WP_zhESrm1SWr7g0Bvw6xbuOo1m2iCnwCcv-M_pkA2'}
