# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product].[196426]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
query2 = "select (Version.[Version Name]*Product.[Product].[196426]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1) 
O9DataLake.register("DPBaseInputs",DataSource.LS, ResourceType.IBPL, query2)
# Out:
# 2023-01-05 10:09:07,985 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:07,989 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:08,098 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 89
# 2023-01-05 10:09:13,108 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:13,112 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:13,213 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 4120
# 2023-01-05 10:09:18,244 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:18,247 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:18,322 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 89
# 2023-01-05 10:09:23,330 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:23,333 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:23,439 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 4120
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
# 5     CurrentWorkingView            196426          W42-2017
# 6     CurrentWorkingView            196426          W44-2017
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                   11.0
# 1                    ALL                 ALL                   11.0
# 2                    ALL                 ALL                   11.0
# 3                    ALL                 ALL                   11.0
# 4                    ALL                 ALL                   11.0
# 5                    ALL                 ALL                   11.0
# 6                    ALL                 ALL                   11.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
# 5                    NaN              NaN              NaN            10.0
# 6                    NaN              NaN              NaN            10.0

# %%
#getting input from dataLake

sales = O9DataLake.get('sales_df')
dpbaseinputs = O9DataLake.get('DPBaseInputs')

#User Script
import logging
out_df1 = None
logger = logging.getLogger('o9_logger')
#logger.info(f'Records count in sales dataframe : {sales.shape}')
#logger.info(f'Records count in DPBaseInputs dataframe : {dpbaseinputs.shape}')
logger.warning("Hello warning")
logger.error("Hello error")
logger.warning("Hello warning")

#pushing output to the DataLake
O9DataLake.put('out_df1',sales)
# Out:
# 2023-01-05 10:09:34,720 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:34,724 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:34,803 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 89
# 2023-01-05 10:09:39,811 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:39,815 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:39,891 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 4120
# 2023-01-05 10:09:44,914 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-05 10:09:44,918 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:57,670 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 824
# 2023-01-05 10:09:57,675 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-05 10:09:57,675 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/user]
# 2023-01-05 10:09:57,680 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:57,951 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 1756
# 2023-01-05 10:09:57,957 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:09:58,049 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=11qx4vtyj1uj45ka2qptcabm HTTP/1.1" 200 824
# 2023-01-05 10:09:58,054 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-05 10:10:00,622 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 461
# 2023-01-05 10:10:00,626 : srishtisingh_5502 :200, OK
# 2023-01-05 10:10:00,628 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.out_df1.csv\",\"SheetName\":\"Fact.out_df1.csv\",\"TotalRows\":7,\"ProcessedRows\":7,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [7]. Successfully Processed Rows: [7].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2\"}]","QueryGuid":"e90effab-69f0-47e8-a630-e04392f520ab","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsActuals","Mean Pricing Save PCT","Placement Count","Promotion Count","DPSellOutPrice"]}}}}
# 2023-01-05 10:10:00,629 : srishtisingh_5502 :{'FileName': 'Fact.out_df1.csv', 'SheetName': 'Fact.out_df1.csv', 'TotalRows': 7, 'ProcessedRows': 7, 'Status': 'Success', 'Messages': ['Total Rows: [7]. Successfully Processed Rows: [7].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2'}
