# %%
#This cells needs to be ignored
#Here we are validating the create plugin functionality in Jhub
#All cells are Assumed to be script cells, unless explicitly marked as o9_ignore

# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]}) limit 10;"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1)
# Out:
# 2023-01-03 06:31:08,512 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-03 06:31:08,515 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:08,653 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-03 06:31:13,662 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-03 06:31:13,665 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:13,809 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
# 5     CurrentWorkingView            196426          W42-2017
# 6     CurrentWorkingView            196426          W44-2017
# 7     CurrentWorkingView            208821          W49-2015
# 8     CurrentWorkingView            208821          W50-2015
# 9     CurrentWorkingView            208821          W51-2015
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                    5.0
# 1                    ALL                 ALL                    5.0
# 2                    ALL                 ALL                    5.0
# 3                    ALL                 ALL                    5.0
# 4                    ALL                 ALL                    5.0
# 5                    ALL                 ALL                    5.0
# 6                    ALL                 ALL                    5.0
# 7                    ALL                 ALL                    5.0
# 8                    ALL                 ALL                    5.0
# 9                    ALL                 ALL                    5.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
# 5                    NaN              NaN              NaN            10.0
# 6                    NaN              NaN              NaN            10.0
# 7                    NaN              2.0              NaN             NaN
# 8                    NaN              2.0              NaN             NaN
# 9                    NaN              2.0              NaN             NaN

# %%
#getting input from dataLake

#getting input from dataLake

sales = O9DataLake.get('sales_df')


#User Script
import logging
out_df1 = None
logger = logging.getLogger('o9_logger')
logger.info(f'Records count in sales dataframe : {sales.shape}')
sales.head()
# Out:
# 2023-01-03 06:31:24,759 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-03 06:31:24,764 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:24,878 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-03 06:31:29,886 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-03 06:31:29,890 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:30,032 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-03 06:31:35,052 : srishtisingh_5502 :Records count in sales dataframe : (10, 10)
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
#
#   SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                    5.0
# 1                    ALL                 ALL                    5.0
# 2                    ALL                 ALL                    5.0
# 3                    ALL                 ALL                    5.0
# 4                    ALL                 ALL                    5.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0

# %%
#pushing output to the DataLake
sales["DPSellOutUnitsActuals"] = "12.0"
O9DataLake.put('out_df1',sales)
# Out:
# 2023-01-03 06:31:49,062 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:49,152 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=11qx4vtyj1uj45ka2qptcabm HTTP/1.1" 200 None
# 2023-01-03 06:31:49,155 : srishtisingh_5502 :Uploading LOCAL file: /tmp/tmpr231eml1/Fact.out_df1.csv
# 2023-01-03 06:31:49,157 : srishtisingh_5502 :Is the file parquet: False
# 2023-01-03 06:31:49,158 : srishtisingh_5502 :Uploading /tmp/tmpr231eml1/Fact.out_df1.csv to Live Server cloud
# 2023-01-03 06:31:49,159 : srishtisingh_5502 :File size less than 256 MB
# 2023-01-03 06:31:49,160 : srishtisingh_5502 :Uploading to /fileUpload endpoint
# 2023-01-03 06:31:49,161 : srishtisingh_5502 :Uploading /tmp/tmpr231eml1/Fact.out_df1.csv to Live Server cloud
# 2023-01-03 06:31:49,167 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:51,424 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/upload/fileUpload HTTP/1.1" 200 None
# 2023-01-03 06:31:51,428 : srishtisingh_5502 :Uploaded the file successfully
# 2023-01-03 06:31:51,429 : srishtisingh_5502 :Uploading cloud files at: "azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2"
# 2023-01-03 06:31:51,430 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/framework/sessions/session]
# 2023-01-03 06:31:51,437 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:51,522 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 None
# 2023-01-03 06:31:51,526 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-03 06:31:51,528 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://mygenieazure.o9solutions.com/api/user]
# 2023-01-03 06:31:51,531 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:51,793 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 None
# 2023-01-03 06:31:51,799 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:51,910 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=11qx4vtyj1uj45ka2qptcabm HTTP/1.1" 200 None
# 2023-01-03 06:31:51,917 : srishtisingh_5502 :Starting new HTTPS connection (1): mygenieazure.o9solutions.com:443
# 2023-01-03 06:31:54,375 : srishtisingh_5502 :https://mygenieazure.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 None
# 2023-01-03 06:31:54,378 : srishtisingh_5502 :200, OK
# 2023-01-03 06:31:54,380 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.out_df1.csv\",\"SheetName\":\"Fact.out_df1.csv\",\"TotalRows\":10,\"ProcessedRows\":10,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [10]. Successfully Processed Rows: [10].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2\"}]","QueryGuid":"18a92bb8-a047-49b6-a55e-b5dd89abcc18","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsActuals","Mean Pricing Save PCT","Placement Count","Promotion Count","DPSellOutPrice"]}}}}
# 2023-01-03 06:31:54,381 : srishtisingh_5502 :{'FileName': 'Fact.out_df1.csv', 'SheetName': 'Fact.out_df1.csv', 'TotalRows': 10, 'ProcessedRows': 10, 'Status': 'Success', 'Messages': ['Total Rows: [10]. Successfully Processed Rows: [10].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCBb7W5Pos9YT7xPNvmWLQcstpUHxf3FCrS49exMY-SvVw2'}

# %%
sales.head()
# Out:
#   Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0     CurrentWorkingView            196426          W03-2016
# 1     CurrentWorkingView            196426          W05-2016
# 2     CurrentWorkingView            196426          W08-2016
# 3     CurrentWorkingView            196426          W13-2016
# 4     CurrentWorkingView            196426          W48-2016
#
#   SalesAccount.[Account] Location.[Location] DPSellOutUnitsActuals  \
# 0                    ALL                 ALL                  10.0
# 1                    ALL                 ALL                  10.0
# 2                    ALL                 ALL                  10.0
# 3                    ALL                 ALL                  10.0
# 4                    ALL                 ALL                  10.0
#
#    Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                    NaN              NaN              NaN            10.0
# 1                    NaN              NaN              NaN            10.0
# 2                    NaN              NaN              NaN            10.0
# 3                    NaN              NaN              NaN            10.0
# 4                    NaN              NaN              NaN            10.0
