# %%
from o9_common_utils.O9DataLake import O9DataLake, ResourceType, DataSource
query1 = "select (Version.[Version Name]*Product.[Product]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
query2 = "select (Version.[Version Name]*Product.[Product]*Time.FiscalWeek*SalesAccount.[Account]*Location.[Location]*{Measure.[DPSellOutUnitsActuals],Measure.[Mean Pricing Save PCT],Measure.[Placement Count],Measure.[Promotion Count],Measure.[DPSellOutPrice]});"
O9DataLake.register("sales_df",DataSource.LS, ResourceType.IBPL, query1) 
O9DataLake.register("DPBaseInputs",DataSource.LS, ResourceType.IBPL, query2)
# Out:
# 2023-01-30 05:52:04,731 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:04,735 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:04,876 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:52:09,885 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:09,888 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:10,040 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:52:15,067 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:15,070 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:15,169 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:52:20,176 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:20,179 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:20,334 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
#     Version.[Version Name] Product.[Product] Time.[FiscalWeek]  \
# 0       CurrentWorkingView            196426          W03-2016
# 1       CurrentWorkingView            196426          W05-2016
# 2       CurrentWorkingView            196426          W08-2016
# 3       CurrentWorkingView            196426          W13-2016
# 4       CurrentWorkingView            196426          W48-2016
# ..                     ...               ...               ...
# 162     CurrentWorkingView            208821          W48-2018
# 163     CurrentWorkingView            208821          W49-2018
# 164     CurrentWorkingView            208821          W50-2018
# 165     CurrentWorkingView            208821          W51-2018
# 166     CurrentWorkingView            208821          W52-2018
#
#     SalesAccount.[Account] Location.[Location]  DPSellOutUnitsActuals  \
# 0                      ALL                 ALL                   11.0
# 1                      ALL                 ALL                   11.0
# 2                      ALL                 ALL                   11.0
# 3                      ALL                 ALL                   11.0
# 4                      ALL                 ALL                   11.0
# ..                     ...                 ...                    ...
# 162                    ALL                 ALL                    NaN
# 163                    ALL                 ALL                    NaN
# 164                    ALL                 ALL                    NaN
# 165                    ALL                 ALL                    NaN
# 166                    ALL                 ALL                    NaN
#
#      Mean Pricing Save PCT  Placement Count  Promotion Count  DPSellOutPrice
# 0                      NaN              NaN              NaN            10.0
# 1                      NaN              NaN              NaN            10.0
# 2                      NaN              NaN              NaN            10.0
# 3                      NaN              NaN              NaN            10.0
# 4                      NaN              NaN              NaN            10.0
# ..                     ...              ...              ...             ...
# 162                    0.5              1.0              1.0             NaN
# 163                    NaN              1.0              NaN             NaN
# 164                    NaN              1.0              NaN             NaN
# 165                    NaN              1.0              NaN             NaN
# 166                    NaN              1.0              NaN             NaN
#
# [167 rows x 10 columns]

# %%
"""
exec plugin instance [CsvMGIP1_CsvMGIP2_CsvMGPrimDf_CsvMGOP1_Slice] for measures {[DPSellOutUnitsActuals]} using scope ([Product].[Product].Filter(#.Name in {[196426],[208821]}) * [Time].[Day] * [Version].[Version Name].[CurrentWorkingView]);

"""
import logging
from sklearn import tree

logger = logging.getLogger('o9_logger')

out_df = None
input_df = O9DataLake.get('sales_df')
predict_df = O9DataLake.get('DPBaseInputs')
if predict_df is not None and len(predict_df.index) > 0:
    x = input_df[['Mean Pricing Save PCT', 'Placement Count', 'Promotion Count', 'DPSellOutPrice']]
    y = input_df[['DPSellOutUnitsActuals']]
    x = x.fillna(0).values
    y = y.fillna(0).values

    clf = tree.DecisionTreeRegressor()
    clf = clf.fit(x, y)

    predict = predict_df[['Mean Pricing Save PCT', 'Placement Count', 'Promotion Count', 'DPSellOutPrice']].fillna(0).values
    # predict_keys = predict_df[['Time.[FiscalWeek]', 'Product.[Product]', 'Version.[Version Name]', 'SalesAccount.[Account]',                               'Location.[Location]']]
    # predict_keys["Product.[Product]"] = pd.to_numeric(predict_keys["Product.[Product]"], downcast='integer')
    predict_values = clf.predict(predict)
    predict_df["DPSellOutUnitsFcst"] = predict_values
    #out_df = pd.concat([predict_keys, out_df_part], axis=1)
    out_df=predict_df[['Time.[FiscalWeek]', 'Product.[Product]', 'Version.[Version Name]', 'SalesAccount.[Account]','Location.[Location]','DPSellOutUnitsFcst']]
    logger.info(out_df)

else:
    out_df = None

O9DataLake.put('DPBaseOutput1',out_df)

O9DataLake.put('DPBaseOutput2',out_df)
# Out:
# 2023-01-30 05:52:50,815 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:50,818 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:50,915 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:52:55,924 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:52:55,928 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:52:56,038 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:53:01,061 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:53:01,064 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:01,175 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:53:06,184 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/ibplquery/5502/ExecuteCompactJsonQuery]
# 2023-01-30 05:53:06,187 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:06,302 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteCompactJsonQuery HTTP/1.1" 200 None
# 2023-01-30 05:53:11,327 : srishtisingh_5502 :    Time.[FiscalWeek] Product.[Product] Version.[Version Name]  \
# 0            W03-2016            196426     CurrentWorkingView
# 1            W05-2016            196426     CurrentWorkingView
# 2            W08-2016            196426     CurrentWorkingView
# 3            W13-2016            196426     CurrentWorkingView
# 4            W48-2016            196426     CurrentWorkingView
# ..                ...               ...                    ...
# 162          W48-2018            208821     CurrentWorkingView
# 163          W49-2018            208821     CurrentWorkingView
# 164          W50-2018            208821     CurrentWorkingView
# 165          W51-2018            208821     CurrentWorkingView
# 166          W52-2018            208821     CurrentWorkingView
#
#     SalesAccount.[Account] Location.[Location]  DPSellOutUnitsFcst
# 0                      ALL                 ALL                11.0
# 1                      ALL                 ALL                11.0
# 2                      ALL                 ALL                11.0
# 3                      ALL                 ALL                11.0
# 4                      ALL                 ALL                11.0
# ..                     ...                 ...                 ...
# 162                    ALL                 ALL                 0.0
# 163                    ALL                 ALL                 0.0
# 164                    ALL                 ALL                 0.0
# 165                    ALL                 ALL                 0.0
# 166                    ALL                 ALL                 0.0
#
# [167 rows x 6 columns]
# 2023-01-30 05:53:11,364 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:11,468 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=tlbzbb324d2yey0r14zglmqs HTTP/1.1" 200 None
# 2023-01-30 05:53:11,471 : srishtisingh_5502 :Uploading LOCAL file: /tmp/tmp5cm62jot/Fact.DPBaseOutput1.csv
# 2023-01-30 05:53:11,472 : srishtisingh_5502 :Is the file parquet: False
# 2023-01-30 05:53:11,474 : srishtisingh_5502 :Uploading /tmp/tmp5cm62jot/Fact.DPBaseOutput1.csv to Live Server cloud
# 2023-01-30 05:53:11,474 : srishtisingh_5502 :File size less than 256 MB
# 2023-01-30 05:53:11,475 : srishtisingh_5502 :Uploading to /fileUpload endpoint
# 2023-01-30 05:53:11,476 : srishtisingh_5502 :Uploading /tmp/tmp5cm62jot/Fact.DPBaseOutput1.csv to Live Server cloud
# 2023-01-30 05:53:11,479 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:13,937 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/upload/fileUpload HTTP/1.1" 200 None
# 2023-01-30 05:53:13,941 : srishtisingh_5502 :Uploaded the file successfully
# 2023-01-30 05:53:13,942 : srishtisingh_5502 :Uploading cloud files at: "azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeKr45t1rKmeODFHbTJ0iDQ2"
# 2023-01-30 05:53:13,943 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/framework/sessions/session]
# 2023-01-30 05:53:13,946 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:14,026 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 None
# 2023-01-30 05:53:14,030 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-30 05:53:14,031 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/user]
# 2023-01-30 05:53:14,034 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:14,288 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 None
# 2023-01-30 05:53:14,295 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:14,400 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=tlbzbb324d2yey0r14zglmqs HTTP/1.1" 200 None
# 2023-01-30 05:53:14,406 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:17,302 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 None
# 2023-01-30 05:53:17,306 : srishtisingh_5502 :200, OK
# 2023-01-30 05:53:17,307 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.DPBaseOutput1.csv\",\"SheetName\":\"Fact.DPBaseOutput1.csv\",\"TotalRows\":167,\"ProcessedRows\":167,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [167]. Successfully Processed Rows: [167].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeKr45t1rKmeODFHbTJ0iDQ2\"}]","QueryGuid":"8a3e737a-64d5-4e93-b31e-925b019115e3","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsFcst"]}}}}
# 2023-01-30 05:53:17,308 : srishtisingh_5502 :{'FileName': 'Fact.DPBaseOutput1.csv', 'SheetName': 'Fact.DPBaseOutput1.csv', 'TotalRows': 167, 'ProcessedRows': 167, 'Status': 'Success', 'Messages': ['Total Rows: [167]. Successfully Processed Rows: [167].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeKr45t1rKmeODFHbTJ0iDQ2'}
# 2023-01-30 05:53:17,314 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:17,425 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=tlbzbb324d2yey0r14zglmqs HTTP/1.1" 200 None
# 2023-01-30 05:53:17,428 : srishtisingh_5502 :Uploading LOCAL file: /tmp/tmpesiy98pp/Fact.DPBaseOutput2.csv
# 2023-01-30 05:53:17,429 : srishtisingh_5502 :Is the file parquet: False
# 2023-01-30 05:53:17,430 : srishtisingh_5502 :Uploading /tmp/tmpesiy98pp/Fact.DPBaseOutput2.csv to Live Server cloud
# 2023-01-30 05:53:17,431 : srishtisingh_5502 :File size less than 256 MB
# 2023-01-30 05:53:17,432 : srishtisingh_5502 :Uploading to /fileUpload endpoint
# 2023-01-30 05:53:17,432 : srishtisingh_5502 :Uploading /tmp/tmpesiy98pp/Fact.DPBaseOutput2.csv to Live Server cloud
# 2023-01-30 05:53:17,436 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:19,713 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/upload/fileUpload HTTP/1.1" 200 None
# 2023-01-30 05:53:19,717 : srishtisingh_5502 :Uploaded the file successfully
# 2023-01-30 05:53:19,718 : srishtisingh_5502 :Uploading cloud files at: "azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeBn0ooPwqk4nDiEel-L1zA2"
# 2023-01-30 05:53:19,719 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/framework/sessions/session]
# 2023-01-30 05:53:19,722 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:19,798 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session HTTP/1.1" 200 None
# 2023-01-30 05:53:19,801 : srishtisingh_5502 :logged into tenant pyplatformhivetest successfully
# 2023-01-30 05:53:19,802 : srishtisingh_5502 :IbplClient: WebApi Request Url = [https://myazureqatest.o9solutions.com/api/user]
# 2023-01-30 05:53:19,805 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:20,062 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/user HTTP/1.1" 200 None
# 2023-01-30 05:53:20,069 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:20,173 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "GET /api/framework/sessions/session/authToken?authToken=tlbzbb324d2yey0r14zglmqs HTTP/1.1" 200 None
# 2023-01-30 05:53:20,178 : srishtisingh_5502 :Starting new HTTPS connection (1): myazureqatest.o9solutions.com:443
# 2023-01-30 05:53:22,629 : srishtisingh_5502 :https://myazureqatest.o9solutions.com:443 "POST /api/ibplquery/5502/ExecuteQuery HTTP/1.1" 200 None
# 2023-01-30 05:53:22,633 : srishtisingh_5502 :200, OK
# 2023-01-30 05:53:22,634 : srishtisingh_5502 :Response json:
# {"Result":"[{\"FileName\":\"Fact.DPBaseOutput2.csv\",\"SheetName\":\"Fact.DPBaseOutput2.csv\",\"TotalRows\":167,\"ProcessedRows\":167,\"Status\":\"Success\",\"Messages\":[\"Total Rows: [167]. Successfully Processed Rows: [167].\"],\"FileId\":\"azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeBn0ooPwqk4nDiEel-L1zA2\"}]","QueryGuid":"cbb03e42-dfbd-4b12-9a43-ff5ba0e43802","ImpactHeader":{"TenantId":5502,"TransactionId":"00000000-0000-0000-0000-000000000000","UpdatedMembers":null,"CreatedMembers":null,"DeletedMembers":null,"ModelImpact":{"DemandPlanning.Core.Inputs":{"DPBaseInputs":["DPSellOutUnitsFcst"]}}}}
# 2023-01-30 05:53:22,635 : srishtisingh_5502 :{'FileName': 'Fact.DPBaseOutput2.csv', 'SheetName': 'Fact.DPBaseOutput2.csv', 'TotalRows': 167, 'ProcessedRows': 167, 'Status': 'Success', 'Messages': ['Total Rows: [167]. Successfully Processed Rows: [167].'], 'FileId': 'azure://IvrkBaeWLfmAdgA63s0q-YQjS9rnxeYLls4-lXy8ZCCxZGqC6V8ENwsS2GlAHvzLeBn0ooPwqk4nDiEel-L1zA2'}
